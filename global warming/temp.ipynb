# %% [markdown]
# Temperature

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('temperature.csv')
df
# Out:
#               Region  Country  State      City  Month   Day    Year  \
# 0             Africa  Algeria    NaN   Algiers    1.0   1.0  1995.0
# 1             Africa  Algeria    NaN   Algiers    1.0   2.0  1995.0
# 2             Africa  Algeria    NaN   Algiers    1.0   3.0  1995.0
# 3             Africa  Algeria    NaN   Algiers    1.0   4.0  1995.0
# 4             Africa  Algeria    NaN   Algiers    1.0   5.0  1995.0
# ...              ...      ...    ...       ...    ...   ...     ...
# 1014929  Middle East   Israel    NaN  Tel Aviv   10.0  24.0  1995.0
# 1014930  Middle East   Israel    NaN  Tel Aviv   10.0  25.0  1995.0
# 1014931  Middle East   Israel    NaN  Tel Aviv   10.0  26.0  1995.0
# 1014932  Middle East   Israel    NaN  Tel Aviv   10.0  27.0  1995.0
# 1014933  Middle East       Is    NaN       NaN    NaN   NaN     NaN
#
#          AvgTemperature
# 0                  64.2
# 1                  49.4
# 2                  48.8
# 3                  46.4
# ...

# %%
type(df['Country'])
# Out:
# pandas.core.series.Series

# %%
df = df[['Region','Country','Year','AvgTemperature']]
df.head
# Out:
# <bound method NDFrame.head of               Region  Country    Year  AvgTemperature
# 0             Africa  Algeria  1995.0            64.2
# 1             Africa  Algeria  1995.0            49.4
# 2             Africa  Algeria  1995.0            48.8
# 3             Africa  Algeria  1995.0            46.4
# 4             Africa  Algeria  1995.0            47.9
# ...              ...      ...     ...             ...
# 1014929  Middle East   Israel  1995.0            90.0
# 1014930  Middle East   Israel  1995.0            90.0
# 1014931  Middle East   Israel  1995.0            90.0
# 1014932  Middle East   Israel  1995.0            90.0
# 1014933  Middle East       Is     NaN             NaN
#
# [1014934 rows x 4 columns]>

# %% [markdown]
# world avg temp

# %%
df1 = df[['Year','AvgTemperature']]

# %%
df1 = df1.groupby('Year')['AvgTemperature'].median().reset_index()
df1
# Out:
#       Year  AvgTemperature
# 0    200.0            90.0
# 1    201.0            90.0
# 2   1995.0            67.5
# 3   1996.0            67.0
# 4   1997.0            67.5
# 5   1998.0            68.7
# 6   1999.0            68.3
# 7   2000.0            67.8
# 8   2001.0            67.9
# 9   2002.0            68.1
# 10  2003.0            68.8
# 11  2004.0            67.7
# 12  2005.0            67.5
# 13  2006.0            67.9
# 14  2007.0            67.2
# 15  2008.0            66.3
# 16  2009.0            67.2
# 17  2010.0            67.6
# 18  2011.0            66.7
# 19  2012.0            66.6
# 20  2013.0            66.6
# 21  2014.0            66.3
# 22  2015.0            66.9
# 23  2016.0            67.3
# 24  2017.0            66.8
# 25  2018.0            67.7
# 26  2019.0            67.3
# 27  2020.0            59.0

# %%
df1 = df1.iloc[2:-1, : ]
df1['Change_Temp'] = df1['AvgTemperature'] - df1['AvgTemperature'].iloc[0]
# Out:
# C:\Users\wasim\AppData\Local\Temp\ipykernel_8008\2074660259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Change_Temp'] = df1['AvgTemperature'] - df1['AvgTemperature'].iloc[0]

# %%
plt.plot(df1['Year'], df1['Change_Temp'], label='CO2', color='g')
plt.xlabel("Year")
plt.ylabel('Change_Temp')
plt.title('Change_Temp')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# CONTINANATE AVG TEMP

# %%
df2 = df[['Region','AvgTemperature']]
df2
# Out:
#               Region  AvgTemperature
# 0             Africa            64.2
# 1             Africa            49.4
# 2             Africa            48.8
# 3             Africa            46.4
# 4             Africa            47.9
# ...              ...             ...
# 1014929  Middle East            90.0
# 1014930  Middle East            90.0
# 1014931  Middle East            90.0
# 1014932  Middle East            90.0
# 1014933  Middle East             NaN
#
# [1014934 rows x 2 columns]

# %%
min_temp = df2.groupby('Region')['AvgTemperature'].min().reset_index()
min_temp
# Out:
#                     Region  AvgTemperature
# 0                   Africa            33.3
# 1                     Asia           -37.2
# 2  Australia/South Pacific            30.7
# 3                   Europe           -20.4
# 4              Middle East            50.5

# %%
max_temp = df2.groupby('Region')['AvgTemperature'].max().reset_index()
max_temp
# Out:
#                     Region  AvgTemperature
# 0                   Africa           102.8
# 1                     Asia           103.7
# 2  Australia/South Pacific            96.8
# 3                   Europe           102.5
# 4              Middle East           103.3

# %%
change_temp = max_temp['AvgTemperature'] - min_temp['AvgTemperature']
change_temp
# Out:
# 0     69.5
# 1    140.9
# 2     66.1
# 3    122.9
# 4     52.8
# Name: AvgTemperature, dtype: float64

# %%
plt.bar(max_temp['Region'], change_temp) 
plt.xlabel('Region')
plt.ylabel('Average Temperature (°F)')
plt.title('Change in Temprature (°F)')
plt.xticks(rotation=45 )
plt.show()

# %% [markdown]
# CONLUSION--->>>
# 1. The average tempreature of earth is increasing with time and it is directly propertion to the rate of avg carbon emission of the world
# 2. max temp change in asia region, and minimum for middle East
